# %%
import plotly.express as px

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({"X":np.random.rand(50),
                "Y":np.random.rand(50),
                "Z":np.random.rand(50),
                "C":np.random.randint(0,4,50)})

# %%
df
# Out:
#            X         Y         Z  C
# 0   0.104970  0.839791  0.054190  0
# 1   0.187191  0.986087  0.714285  1
# 2   0.386287  0.281835  0.576861  0
# 3   0.096684  0.561447  0.150991  0
# 4   0.506730  0.937010  0.423252  0
# 5   0.537143  0.709474  0.375078  1
# 6   0.604837  0.407295  0.789945  3
# 7   0.997422  0.425439  0.730701  3
# 8   0.432191  0.627868  0.472543  0
# 9   0.135562  0.830708  0.258247  0
# 10  0.172099  0.654947  0.387697  1
# 11  0.197486  0.112991  0.101739  0
# 12  0.228527  0.042881  0.497223  3
# 13  0.715399  0.808442  0.161700  1
# 14  0.100839  0.554861  0.240733  3
# 15  0.083304  0.797316  0.177202  1
# 16  0.999795  0.928786  0.847265  0
# 17  0.351655  0.933990  0.270832  3
# 18  0.367225  0.686603  0.156290  0
# 19  0.244155  0.277844  0.114699  0
# 20  0.234091  0.062194  0.654159  3
# 21  0.798460  0.460858  0.629047  2
# 22  0.563597  0.531794  0.226083  3
# 23  0.687356  0.578880  0.900441  1
# 24  0.668290  0.114396  0.469473  2
# ...

# %%
fig=px.scatter_3d(df,x="X",y="Y",z="Z",color="C")
fig.show()
# Out:
# <div>                            <div id="fa9d35af-0742-44b2-975d-3fd8c1c26978" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa9d35af-0742-44b2-975d-3fd8c1c26978")) {                    Plotly.newPlot(                        "fa9d35af-0742-44b2-975d-3fd8c1c26978",                        [{"hovertemplate": "X=%{x}<br>Y=%{y}<br>Z=%{z}<br>C=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [0, 1, 0, 0, 0, 1, 3, 3, 0, 0, 1, 0, 3, 1, 3, 1, 0, 3, 0, 0, 3, 2, 3, 1, 2, 2, 2, 3, 1, 1, 2, 2, 3, 3, 2, 0, 1, 2, 1, 3, 0, 2, 1, 3, 3, 3, 2, 0, 2, 2], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": [0.10496969615252705, 0.18719123033324891, 0.3862
# ...

# %%
import seaborn as sns

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
px.scatter_3d(iris,x="sepal_length",
              y="petal_length",
              z="petal_width",
              color="species")
fig.show()
# Out:
# <div>                            <div id="c0cc5816-8784-43bf-b48f-4ee33cf17f45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0cc5816-8784-43bf-b48f-4ee33cf17f45")) {                    Plotly.newPlot(                        "c0cc5816-8784-43bf-b48f-4ee33cf17f45",                        [{"hovertemplate": "X=%{x}<br>Y=%{y}<br>Z=%{z}<br>C=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [0, 1, 0, 0, 0, 1, 3, 3, 0, 0, 1, 0, 3, 1, 3, 1, 0, 3, 0, 0, 3, 2, 3, 1, 2, 2, 2, 3, 1, 1, 2, 2, 3, 3, 2, 0, 1, 2, 1, 3, 0, 2, 1, 3, 3, 3, 2, 0, 2, 2], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": [0.10496969615252705, 0.18719123033324891, 0.3862
# ...

# %%
from sklearn.feature_selection import SelectKBest

# %%
y=np.asarray(iris.species)
X=np.asarray(iris.drop("species",axis=1))

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
mdl=SelectKBest(k=3)
X_new=mdl.fit_transform(X,y)

# %%
X_new.shape
# Out:
# (150, 3)

# %%
df2=pd.DataFrame({"X":X_new[:,0],
                 "Y":X_new[:,1],
                 "Z":X_new[:,2],
                 "C":Y})

# %%
fig=px.scatter_3d(df2,x="X",y="Y",z="Z",color="Y")

# %%
fig.show()
# Out:
# <div>                            <div id="d33b113f-d13c-4da7-8874-0a7d7c750b78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d33b113f-d13c-4da7-8874-0a7d7c750b78")) {                    Plotly.newPlot(                        "d33b113f-d13c-4da7-8874-0a7d7c750b78",                        [{"hovertemplate": "X=%{x}<br>Y=%{marker.color}<br>Z=%{z}<extra></extra>", "legendgroup": "", "marker": {"color": [1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4, 1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1.0, 1.7, 1.9, 1.6, 1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3, 1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5, 4.9, 4.0, 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4.0, 4.7, 3.6, 4.4, 4.5, 4.1, 4.5, 3.9, 4.8
# ...
